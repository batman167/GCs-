# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical

# Seed for reproducibility
np.random.seed(0)

# Number of samples
num_samples = 1000

# Generate synthetic data
data = {
    'Age': np.random.randint(30, 80, size=num_samples),
    'Age_normalized': np.random.randint(1, 5, size=num_samples),
    'Sex': np.random.choice([0, 1], size=num_samples),  # 0: Male, 1: Female
    'Smoking': np.random.choice([0, 1], size=num_samples),  # 0: Non-smoker, 1: Smoker
    'Tumor_Size': np.random.uniform(1.0, 5.0, size=num_samples),  # Tumor size in cm
    'Tumor_Grade': np.random.randint(1, 4, size=num_samples),  # Tumor grade: 1, 2, 3
    'ER_Status': np.random.choice(['Positive', 'Negative'], size=num_samples),
    'PR_Status': np.random.choice(['Positive', 'Negative'], size=num_samples),
    'HER2_Status': np.random.choice(['Positive', 'Negative'], size=num_samples),
    'Lymph_Node_Involvement': np.random.randint(0, 10, size=num_samples),  # Number of involved lymph nodes
    'VDW': np.random.uniform(-60, -40, size=num_samples),
    'EEL': np.random.uniform(-30, -20, size=num_samples),
    'EPB': np.random.uniform(30, 40, size=num_samples),
    'ENPOLAR': np.random.uniform(-40, -20, size=num_samples),
    'TOTAL': np.random.uniform(-80, -50, size=num_samples),
    'Matching_rates': np.random.uniform(0.2, 0.6, size=num_samples),
    'Centroid_distance': np.random.uniform(40, 60, size=num_samples),
    'Connectivity': np.random.randint(15, 30, size=num_samples),
    'Convex_atoms': np.random.randint(20, 40, size=num_samples),
    'Hydrogen_bonds': np.random.randint(1200, 1600, size=num_samples),
    'response': np.random.choice(['stable', 'partial', 'no'], size=num_samples)
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df.head(10)
# Out:
#    Age  Age_normalized  Sex  Smoking  Tumor_Size  Tumor_Grade ER_Status  \
# 0   74               4    0        1    4.687663            3  Positive
# 1   77               3    0        1    1.869103            1  Positive
# 2   30               2    1        1    1.459697            1  Negative
# 3   33               3    1        0    3.896290            2  Positive
# 4   33               4    0        1    1.813583            3  Negative
# 5   69               4    0        1    1.704415            3  Negative
# 6   39               3    1        1    2.279229            3  Negative
# 7   49               2    0        0    4.267301            3  Negative
# 8   51               4    0        0    3.158146            2  Negative
# 9   66               4    0        1    1.183401            2  Positive
#
#   PR_Status HER2_Status  Lymph_Node_Involvement  ...        EEL        EPB  \
# 0  Negative    Positive                       0  ... -20.685768  30.184369
# ...

# %%
df.shape
# Out:
# (1000, 21)

# %%
label_encoders = {}
for column in ['ER_Status', 'PR_Status', 'HER2_Status', 'response']:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column])
    label_encoders[column] = le

# %%
X = df.drop('response', axis=1)
y = df['response']

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
y_categorical = to_categorical(y)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_categorical, test_size=0.2, random_state=0)

# %%
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))  # 3 classes in target

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, callbacks=[early_stopping])

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')

# Display training history
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])
plt.show()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.2860 - loss: 2.1520 - val_accuracy: 0.3313 - val_loss: 1.8182
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3498 - loss: 1.9219 - val_accuracy: 0.3375 - val_loss: 1.7741
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3648 - loss: 1.8044 - val_accuracy: 0.3187 - val_loss: 1.7399
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3404 - loss: 1.7914 - val_accuracy: 0.3375 - val_loss: 1.7064
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3022 - loss: 1.7409 - val_accuracy: 0.3562 - val_loss: 1.6723
# Epoch 6/50
# ...

# %%
print(df['response'].value_counts())
# Out:
# response
# partial    358
# stable     336
# no         306
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical

# Generate synthetic data (as before)
np.random.seed(0)
num_samples = 1000

data = {
    'Age': np.random.randint(30, 80, size=num_samples),
    'Age_normalized': np.random.randint(1, 5, size=num_samples),
    'Sex': np.random.choice([0, 1], size=num_samples),
    'Smoking': np.random.choice([0, 1], size=num_samples),
    'Tumor_Size': np.random.uniform(1.0, 5.0, size=num_samples),
    'Tumor_Grade': np.random.randint(1, 4, size=num_samples),
    'ER_Status': np.random.choice(['Positive', 'Negative'], size=num_samples),
    'PR_Status': np.random.choice(['Positive', 'Negative'], size=num_samples),
    'HER2_Status': np.random.choice(['Positive', 'Negative'], size=num_samples),
    'Lymph_Node_Involvement': np.random.randint(0, 10, size=num_samples),
    'VDW': np.random.uniform(-60, -40, size=num_samples),
    'EEL': np.random.uniform(-30, -20, size=num_samples),
    'EPB': np.random.uniform(30, 40, size=num_samples),
    'ENPOLAR': np.random.uniform(-40, -20, size=num_samples),
    'TOTAL': np.random.uniform(-80, -50, size=num_samples),
    'Matching_rates': np.random.uniform(0.2, 0.6, size=num_samples),
    'Centroid_distance': np.random.uniform(40, 60, size=num_samples),
    'Connectivity': np.random.randint(15, 30, size=num_samples),
    'Convex_atoms': np.random.randint(20, 40, size=num_samples),
    'Hydrogen_bonds': np.random.randint(1200, 1600, size=num_samples),
    'response': np.random.choice(['stable', 'partial', 'no'], size=num_samples)
}

df = pd.DataFrame(data)

# Preprocessing
# Convert categorical variables to numerical
label_encoders = {}
for column in ['ER_Status', 'PR_Status', 'HER2_Status', 'response']:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column])
    label_encoders[column] = le

# Separate features and target
X = df.drop('response', axis=1)
y = df['response']

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert target to categorical
y_categorical = to_categorical(y)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_categorical, test_size=0.2, random_state=0)

# Define the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dropout(0.4))
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dropout(0.4))
model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dense(3, activation='softmax'))  # 3 classes in target

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, callbacks=[early_stopping])

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')

# Display training history
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])
plt.show()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 91ms/step - accuracy: 0.3437 - loss: 1.3281 - val_accuracy: 0.3187 - val_loss: 1.2693
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3488 - loss: 1.2809 - val_accuracy: 0.3250 - val_loss: 1.2624
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3846 - loss: 1.2432 - val_accuracy: 0.3625 - val_loss: 1.2519
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4020 - loss: 1.2390 - val_accuracy: 0.3500 - val_loss: 1.2546
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4047 - loss: 1.2338 - val_accuracy: 0.3313 - val_loss: 1.2554
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical

# Generate synthetic data with 2 classes for 'response'
np.random.seed(0)
num_samples = 1000

data = {
    'Age': np.random.randint(30, 80, size=num_samples),
    'Age_normalized': np.random.randint(1, 5, size=num_samples),
    'Sex': np.random.choice([0, 1], size=num_samples),
    'Smoking': np.random.choice([0, 1], size=num_samples),
    'Tumor_Size': np.random.uniform(1.0, 5.0, size=num_samples),
    'Tumor_Grade': np.random.randint(1, 4, size=num_samples),
    'ER_Status': np.random.choice(['Positive', 'Negative'], size=num_samples),
    'PR_Status': np.random.choice(['Positive', 'Negative'], size=num_samples),
    'HER2_Status': np.random.choice(['Positive', 'Negative'], size=num_samples),
    'Lymph_Node_Involvement': np.random.randint(0, 10, size=num_samples),
    'VDW': np.random.uniform(-60, -40, size=num_samples),
    'EEL': np.random.uniform(-30, -20, size=num_samples),
    'EPB': np.random.uniform(30, 40, size=num_samples),
    'ENPOLAR': np.random.uniform(-40, -20, size=num_samples),
    'TOTAL': np.random.uniform(-80, -50, size=num_samples),
    'Matching_rates': np.random.uniform(0.2, 0.6, size=num_samples),
    'Centroid_distance': np.random.uniform(40, 60, size=num_samples),
    'Connectivity': np.random.randint(15, 30, size=num_samples),
    'Convex_atoms': np.random.randint(20, 40, size=num_samples),
    'Hydrogen_bonds': np.random.randint(1200, 1600, size=num_samples),
    'response': np.random.choice(['stable', 'partial'], size=num_samples)
}

df = pd.DataFrame(data)

# Preprocessing
# Convert categorical variables to numerical
label_encoders = {}
for column in ['ER_Status', 'PR_Status', 'HER2_Status', 'response']:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column])
    label_encoders[column] = le

# Separate features and target
X = df.drop('response', axis=1)
y = df['response']

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert target to categorical
y_categorical = to_categorical(y)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_categorical, test_size=0.2, random_state=0)

# Define the neural network model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))  # 2 classes in target

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, callbacks=[early_stopping])

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')

# Display training history
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])
plt.show()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.4820 - loss: 1.5728 - val_accuracy: 0.5000 - val_loss: 1.3947
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5122 - loss: 1.4330 - val_accuracy: 0.4750 - val_loss: 1.3482
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5254 - loss: 1.3691 - val_accuracy: 0.4750 - val_loss: 1.3052
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5165 - loss: 1.3097 - val_accuracy: 0.4812 - val_loss: 1.2657
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4725 - loss: 1.2993 - val_accuracy: 0.5063 - val_loss: 1.2274
# Epoch 6/50
# ...

# %%
df
# Out:
#      Age  Age_normalized  Sex  Smoking  Tumor_Size  Tumor_Grade  ER_Status  \
# 0     74               4    0        1    4.687663            3          1
# 1     77               3    0        1    1.869103            1          1
# 2     30               2    1        1    1.459697            1          0
# 3     33               3    1        0    3.896290            2          1
# 4     33               4    0        1    1.813583            3          0
# ..   ...             ...  ...      ...         ...          ...        ...
# 995   67               1    0        1    1.192311            2          1
# 996   71               2    1        0    1.599106            1          0
# 997   47               3    0        0    1.656018            1          1
# 998   46               1    1        1    2.516943            2          0
# 999   78               2    0        1    3.989430            3          1
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.svm import SVC

# %%
X = df.drop('response', axis=1)
y = df['response']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
rf = RandomForestClassifier(n_estimators = 1000, random_state = 42)
rf.fit(X_train, y_train);
y_pred = rf.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.57

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[53, 38],
#        [48, 61]])

# %%
svm = SVC(kernel='linear', C=1.0, random_state=42)
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.52

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[50, 41],
#        [55, 54]])

# %%
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Initialize the RandomForestClassifier
rf = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid,
                           cv=5, n_jobs=-1, verbose=2, scoring='accuracy')

# Fit GridSearchCV
grid_search.fit(X_train, y_train)

# Best parameters and best score
print("Best Parameters:\n", grid_search.best_params_)
print("Best Score:\n", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-53681198e3ba> in <cell line: 9>()
#       7
#       8 # Fit GridSearchCV
# ----> 9 grid_search.fit(X_train, y_train)
#      10
#      11 # Best parameters and best score
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     896                 return results
#     897
# --> 898             self._run_search(evaluate_candidates)
#     899
# ...

# %%
# Get the best model
best_rf = grid_search.best_estimator_

# Make predictions
y_pred = best_rf.predict(X_test)

# Evaluate the model
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Accuracy Score:\n", accuracy_score(y_test, y_pred))
