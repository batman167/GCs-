# %%
import pandas as pd
df1 = pd.read_parquet("hf://datasets/ade-benchmark-corpus/ade_corpus_v2/Ade_corpus_v2_classification/train-00000-of-00001.parquet")

# %%
df2 = pd.read_parquet("hf://datasets/ade-benchmark-corpus/ade_corpus_v2/Ade_corpus_v2_drug_ade_relation/train-00000-of-00001.parquet")

# %%
df3 = pd.read_parquet("hf://datasets/ade-benchmark-corpus/ade_corpus_v2/Ade_corpus_v2_drug_dosage_relation/train-00000-of-00001.parquet")

# %%
df1.head(10)
# Out:
#                                                 text  label
# 0      Intravenous azithromycin-induced ototoxicity.      1
# 1  Immobilization, while Paget's bone disease was...      1
# 2  Unaccountable severe hypercalcemia in a patien...      1
# 3  METHODS: We report two cases of pseudoporphyri...      1
# 4  METHODS: We report two cases of pseudoporphyri...      1
# 5  Naproxen, the most common offender, has been a...      1
# 6  RESULTS: A 44-year-old man taking naproxen for...      1
# 7  RESULTS: A 44-year-old man taking naproxen for...      1
# 8  RESULTS: A 44-year-old man taking naproxen for...      1
# 9  RESULTS: A 44-year-old man taking naproxen for...      1

# %%
df2.head(10)
df2 = df2.drop(columns=['text', 'indexes'], axis=1)

# %%
df2.head(10)
# Out:
#                  drug                         effect
# 0        azithromycin                    ototoxicity
# 1  dihydrotachysterol      increased calcium-release
# 2  dihydrotachysterol                  hypercalcemia
# 3            naproxen                pseudoporphyria
# 4           oxaprozin                pseudoporphyria
# 5            Naproxen  erythropoietic protoporphyria
# 6            naproxen            cutaneous fragility
# 7           oxaprozin            cutaneous fragility
# 8            naproxen                   tense bullae
# 9           oxaprozin                   tense bullae

# %%
df1.head()
# Out:
#                                                 text  label
# 0      Intravenous azithromycin-induced ototoxicity.      1
# 1  Immobilization, while Paget's bone disease was...      1
# 2  Unaccountable severe hypercalcemia in a patien...      1
# 3  METHODS: We report two cases of pseudoporphyri...      1
# 4  METHODS: We report two cases of pseudoporphyri...      1

# %%
df3.head()
# Out:
#                                                 text          drug  \
# 0  An episode of subacute encephalopathy after th...  methotrexate
# 1  She continued to receive regular insulin 4 tim...       insulin
# 2  A 5-month-old infant became lethargic and poor...   brimonidine
# 3  The presented patient was treated with 200 mg ...           TCA
# 4  Central nervous system manifestations of an ib...     ibuprofen
#
#             dosage                                            indexes
# 0       1500 mg/m2  {'drug': {'start_char': [79], 'end_char': [91]...
# 1  4 times per day  {'drug': {'start_char': [33], 'end_char': [40]...
# 2           1 drop  {'drug': {'start_char': [86], 'end_char': [97]...
# 3           200 mg  {'drug': {'start_char': [46, 163], 'end_char':...
# 4         overdose  {'drug': {'start_char': [44], 'end_char': [53]...

# %%
df2.shape
# Out:
# (6821, 2)
