# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('output (4).csv')

# %%
df
# Out:
#                                    case_id case_submitter_id project_id  \
# 0     001cef41-ff86-4d3f-a140-a647ac4b10a1      TCGA-E2-A1IU  TCGA-BRCA
# 1     001cef41-ff86-4d3f-a140-a647ac4b10a1      TCGA-E2-A1IU  TCGA-BRCA
# 2     0045349c-69d9-4306-a403-c9c1fa836644      TCGA-A1-A0SB  TCGA-BRCA
# 3     0045349c-69d9-4306-a403-c9c1fa836644      TCGA-A1-A0SB  TCGA-BRCA
# 4     00807dae-9f4a-4fd1-aac2-82eb11bf2afb      TCGA-A2-A04W  TCGA-BRCA
# ...                                    ...               ...        ...
# 2190  fe7f74b8-20f4-4471-91dc-4cca8c68e5c0      TCGA-A2-A3XZ  TCGA-BRCA
# 2191  fec0da58-1047-44d2-b6d1-c18cceed43dc      TCGA-E9-A295  TCGA-BRCA
# 2192  fec0da58-1047-44d2-b6d1-c18cceed43dc      TCGA-E9-A295  TCGA-BRCA
# 2193  ff0f875f-113a-4c0f-8c0a-4259cd496e6d      TCGA-C8-A26W  TCGA-BRCA
# 2194  ff0f875f-113a-4c0f-8c0a-4259cd496e6d      TCGA-C8-A26W  TCGA-BRCA
#
#      age_at_index days_to_birth               ethnicity  gender  \
# ...

# %%
main = ['treatment_type', 'ethnicity', 'gender', 'race']
for col in main:
  print(f"{col}: {df[col].unique()}")
# Out:
# treatment_type: ['Radiation Therapy, NOS' 'Pharmaceutical Therapy, NOS' "'--"]
# ethnicity: ['not hispanic or latino' 'not reported' 'hispanic or latino' "'--"]
# gender: ['female' 'male' "'--"]
# race: ['white' 'not reported' 'black or african american'
#  'american indian or alaska native' 'asian' "'--"]

# %%
df_scaled = df.drop([ 'case_submitter_id', 'project_id', 'days_to_birth', 'progression_or_recurrence'], axis=1)

# %%
df_scaled
# Out:
#                                    case_id age_at_index  ethnicity  gender  \
# 0     001cef41-ff86-4d3f-a140-a647ac4b10a1           60          2       1
# 1     001cef41-ff86-4d3f-a140-a647ac4b10a1           60          2       1
# 2     0045349c-69d9-4306-a403-c9c1fa836644           70          2       1
# 3     0045349c-69d9-4306-a403-c9c1fa836644           70          2       1
# 4     00807dae-9f4a-4fd1-aac2-82eb11bf2afb           50          2       1
# ...                                    ...          ...        ...     ...
# 2190  fe7f74b8-20f4-4471-91dc-4cca8c68e5c0           46          2       1
# 2191  fec0da58-1047-44d2-b6d1-c18cceed43dc           71          2       1
# 2192  fec0da58-1047-44d2-b6d1-c18cceed43dc           71          2       1
# 2193  ff0f875f-113a-4c0f-8c0a-4259cd496e6d           58          2       1
# 2194  ff0f875f-113a-4c0f-8c0a-4259cd496e6d           58          2       1
#
# ...
